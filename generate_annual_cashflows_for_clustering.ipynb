# %%
import modelx as mx
import pandas as pd

model = mx.read_model('BasicTerm_ME')

# %%
model.Projection.model_point_table
# Out:
#            age_at_entry sex  policy_term  policy_count  sum_assured  \
# policy_id
# 1                    47   M           10            86       622000
# 2                    29   M           20            56       752000
# 3                    51   F           10            83       799000
# 4                    32   F           20            72       422000
# 5                    28   M           15            99       605000
# ...                 ...  ..          ...           ...          ...
# 9996                 47   M           20            25       827000
# 9997                 30   M           15            81       826000
# 9998                 45   F           20            10       783000
# 9999                 39   M           20             9       302000
# 10000                22   F           15            18       576000
#
#            duration_mth
# policy_id
# 1                     1
# 2                   210
# 3                    15
# 4                   125
# ...

# %%
@mx.defcells
def net_cf_annual():
    data = {}
    for m in range(0, max_proj_len(), 12):
        data[int(m/12)] = sum([net_cf(t) for t in range(m, min(m+12, max_proj_len()))])
        
    return pd.DataFrame(data, index=model_point().index)

net_cf_annual()
# Out:
#                      0             1             2             3   \
# policy_id
# 1         -31593.415327  44256.354597  35539.980346  27481.791877
# 2          -5759.096470  -8095.650275  -4620.120114      0.000000
# 3          82362.887570  66291.076528  51255.775806  36104.446727
# 4           4394.879459   2997.353964   1554.661346     62.404578
# 5          11522.464855   8846.022560   7351.796701   5821.013973
# ...                 ...           ...           ...           ...
# 9996        4210.354746    164.457817  -4089.588583  -8572.554257
# 9997       -5569.052690      0.000000      0.000000      0.000000
# 9998        2454.603821   1260.289443      9.377564  -1303.832683
# 9999        2089.285652   2091.186884   1770.638594   1476.461348
# 10000       -644.195630   -114.051868      0.000000      0.000000
#
#                      4             5             6            7            8   \
# policy_id
# ...

# %%
#net_cf_annual().to_excel('cf100.xlsx')

# %%
pvs = model.Projection.pv_net_cf()
pvs
# Out:
# array([397271.91884623,  -9206.66443427,  27977.46459875, ...,
#        -24800.30013994,  31350.88443321,  44836.68717837])

# %%
pd.DataFrame(pvs).to_excel('pvs.xlsx')

# %%
sum(pvs)
# Out:
# 2382715874.0253196
